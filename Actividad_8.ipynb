# %%
import json 
import pandas as pd
import numpy as np
import glob
import Libreria_a01736397 as lp
import importlib
importlib.reload(lp)
# Out:
# <module 'Libreria_a01736397' from 'c:\\Users\\laish\\Downloads\\Carga de datos\\Libreria_a01736397.py'>

# %%
df_csv= lp.cargar_dataset('fffff.csv')

# %%
df_xlsx=lp.cargar_dataset('Antigüedad de saldos 17.03.2023.xlsx')

# %%
df_json=lp.cargar_dataset('data-nl-2015.json')

# %%
df_html=lp.cargar_dataset('Data_Airbnb.html')

# %%
df_csv.isnull().sum()
# Out:
# id                                               0
# listing_url                                      0
# scrape_id                                        0
# last_scraped                                     0
# source                                           0
#                                                 ..
# calculated_host_listings_count                   0
# calculated_host_listings_count_entire_homes      0
# calculated_host_listings_count_private_rooms     0
# calculated_host_listings_count_shared_rooms      0
# reviews_per_month                               67
# Length: 79, dtype: int64

# %%
df_fill= lp.nulos_ffill_df(df_csv)
df_fill
# Out:
# c:\Users\laish\Downloads\Carga de datos\Libreria_a01736397.py:29: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill")
#                id                                       listing_url  \
# 0    2.992450e+06              https://www.airbnb.com/rooms/2992450
# 1    3.820211e+06              https://www.airbnb.com/rooms/3820211
# 2    5.651579e+06              https://www.airbnb.com/rooms/5651579
# 3    6.623339e+06              https://www.airbnb.com/rooms/6623339
# 4    9.005989e+06              https://www.airbnb.com/rooms/9005989
# ..            ...                                               ...
# 442  1.419800e+18  https://www.airbnb.com/rooms/1419803505997334256
# 443  1.430420e+18  https://www.airbnb.com/rooms/1430417055174000914
# 444  1.432820e+18  https://www.airbnb.com/rooms/1432823196473666155
# ...

# %%
df_bfill= lp.nulos_bfill_df(df_csv)
df_bfill
# Out:
# c:\Users\laish\Downloads\Carga de datos\Libreria_a01736397.py:37: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="bfill")
#                id                                       listing_url  \
# 0    2.992450e+06              https://www.airbnb.com/rooms/2992450
# 1    3.820211e+06              https://www.airbnb.com/rooms/3820211
# 2    5.651579e+06              https://www.airbnb.com/rooms/5651579
# 3    6.623339e+06              https://www.airbnb.com/rooms/6623339
# 4    9.005989e+06              https://www.airbnb.com/rooms/9005989
# ..            ...                                               ...
# 442  1.419800e+18  https://www.airbnb.com/rooms/1419803505997334256
# 443  1.430420e+18  https://www.airbnb.com/rooms/1430417055174000914
# 444  1.432820e+18  https://www.airbnb.com/rooms/1432823196473666155
# ...

# %%
df_string= lp.nulos_string_df(df_csv)
df_string
# Out:
#                id     scrape_id    host_id  host_listings_count  \
# 0    2.992450e+06  2.025060e+13    4621559                    1
# 1    3.820211e+06  2.025060e+13   19648678                    4
# 2    5.651579e+06  2.025060e+13   29288920                    2
# 3    6.623339e+06  2.025060e+13   19648678                    4
# 4    9.005989e+06  2.025060e+13   17766924                    1
# ..            ...           ...        ...                  ...
# 442  1.419800e+18  2.025060e+13   51050977                    2
# 443  1.430420e+18  2.025060e+13  418024477                    1
# 444  1.432820e+18  2.025060e+13  531209536                    2
# 445  1.434110e+18  2.025060e+13  466790114                   10
# 446  1.434110e+18  2.025060e+13  466790114                   10
#
#      host_total_listings_count  neighbourhood_group_cleansed   latitude  \
# 0                            5                           NaN  42.657890
# ...

# %%
df_limpio= lp.nulos_prom_df(df_csv)
df_limpio
# Out:
#                id     scrape_id    host_id  host_listings_count  \
# 0    2.992450e+06  2.025060e+13    4621559                    1
# 1    3.820211e+06  2.025060e+13   19648678                    4
# 2    5.651579e+06  2.025060e+13   29288920                    2
# 3    6.623339e+06  2.025060e+13   19648678                    4
# 4    9.005989e+06  2.025060e+13   17766924                    1
# ..            ...           ...        ...                  ...
# 442  1.419800e+18  2.025060e+13   51050977                    2
# 443  1.430420e+18  2.025060e+13  418024477                    1
# 444  1.432820e+18  2.025060e+13  531209536                    2
# 445  1.434110e+18  2.025060e+13  466790114                   10
# 446  1.434110e+18  2.025060e+13  466790114                   10
#
#      host_total_listings_count  neighbourhood_group_cleansed   latitude  \
# 0                            5                           NaN  42.657890
# ...

# %%
df_mediana= lp.nulos_mediana_df(df_csv)
df_mediana
# Out:
#                id     scrape_id    host_id  host_listings_count  \
# 0    2.992450e+06  2.025060e+13    4621559                    1
# 1    3.820211e+06  2.025060e+13   19648678                    4
# 2    5.651579e+06  2.025060e+13   29288920                    2
# 3    6.623339e+06  2.025060e+13   19648678                    4
# 4    9.005989e+06  2.025060e+13   17766924                    1
# ..            ...           ...        ...                  ...
# 442  1.419800e+18  2.025060e+13   51050977                    2
# 443  1.430420e+18  2.025060e+13  418024477                    1
# 444  1.432820e+18  2.025060e+13  531209536                    2
# 445  1.434110e+18  2.025060e+13  466790114                   10
# 446  1.434110e+18  2.025060e+13  466790114                   10
#
#      host_total_listings_count  neighbourhood_group_cleansed   latitude  \
# 0                            5                           NaN  42.657890
# ...

# %%
df_constante= lp.nulos_constante_df(df_csv)
df_constante
# Out:
#                id     scrape_id    host_id  host_listings_count  \
# 0    2.992450e+06  2.025060e+13    4621559                    1
# 1    3.820211e+06  2.025060e+13   19648678                    4
# 2    5.651579e+06  2.025060e+13   29288920                    2
# 3    6.623339e+06  2.025060e+13   19648678                    4
# 4    9.005989e+06  2.025060e+13   17766924                    1
# ..            ...           ...        ...                  ...
# 442  1.419800e+18  2.025060e+13   51050977                    2
# 443  1.430420e+18  2.025060e+13  418024477                    1
# 444  1.432820e+18  2.025060e+13  531209536                    2
# 445  1.434110e+18  2.025060e+13  466790114                   10
# 446  1.434110e+18  2.025060e+13  466790114                   10
#
#      host_total_listings_count  neighbourhood_group_cleansed   latitude  \
# 0                            5                           0.0  42.657890
# ...

# %%
df_identificar= lp.identificar_nulos_df(df_csv)
df_identificar
# Out:
# Total de valores nulos en el DataFrame: 3115
#                                               nulos_por_columna
# id                                                            0
# listing_url                                                   0
# scrape_id                                                     0
# last_scraped                                                  0
# source                                                        0
# ...                                                         ...
# calculated_host_listings_count                                0
# calculated_host_listings_count_entire_homes                   0
# calculated_host_listings_count_private_rooms                  0
# calculated_host_listings_count_shared_rooms                   0
# reviews_per_month                                            67
#
# [79 rows x 1 columns]

# %%
df_limpio= lp.nulos_prom_df(df_csv)
df_limpio
# Out:
#                id     scrape_id    host_id  host_listings_count  \
# 0    2.992450e+06  2.025060e+13    4621559                    1
# 1    3.820211e+06  2.025060e+13   19648678                    4
# 2    5.651579e+06  2.025060e+13   29288920                    2
# 3    6.623339e+06  2.025060e+13   19648678                    4
# 4    9.005989e+06  2.025060e+13   17766924                    1
# ..            ...           ...        ...                  ...
# 442  1.419800e+18  2.025060e+13   51050977                    2
# 443  1.430420e+18  2.025060e+13  418024477                    1
# 444  1.432820e+18  2.025060e+13  531209536                    2
# 445  1.434110e+18  2.025060e+13  466790114                   10
# 446  1.434110e+18  2.025060e+13  466790114                   10
#
#      host_total_listings_count  neighbourhood_group_cleansed   latitude  \
# 0                            5                           NaN  42.657890
# ...

# %%
df_csv.isnull().sum()
# Out:
# id                                               0
# listing_url                                      0
# scrape_id                                        0
# last_scraped                                     0
# source                                           0
#                                                 ..
# calculated_host_listings_count                   0
# calculated_host_listings_count_entire_homes      0
# calculated_host_listings_count_private_rooms     0
# calculated_host_listings_count_shared_rooms      0
# reviews_per_month                               67
# Length: 79, dtype: int64
